# %% [markdown]
# ## Variables

# %% [markdown]
# 1) Crear una variable que contenga un elemento del conjunto de números enteros y luego imprimir por pantalla

# %%
num1 = 5
print(num1)
# Out:
# 5

# %% [markdown]
# 2) Imprimir el tipo de dato de la constante 8.5

# %%
print(type(8.5))
# Out:
# <class 'float'>

# %% [markdown]
# 3) Imprimir el tipo de dato de la variable creada en el punto 1

# %%
print(type(num1))
# Out:
# <class 'int'>

# %% [markdown]
# 4) Crear una variable que contenga tu nombre

# %%
name = "Rhonald"

# %% [markdown]
# 5) Crear una variable que contenga un número complejo

# %%
num2 = 7 + 5j

# %% [markdown]
# 6) Mostrar el tipo de dato de la variable crada en el punto 5

# %%
print(type(num2))
# Out:
# <class 'complex'>

# %% [markdown]
# 7) Crear una variable que contenga el valor del número Pi redondeado a 4 decimales

# %%
import numpy as np
print(round(np.pi, 4))
# Out:
# 3.1416

# %% [markdown]
# 8) Crear una variable que contenga el valor 'True' y otra que contenga el valor True. ¿Se trata de lo mismo?

# %%
elvi = "True"
elvi1 = True
#no son el mismo tipo de variable

# %% [markdown]
# 9) Imprimir el tipo de dato correspondientes a las variables creadas en el punto 8

# %%
print(type(elvi))
print(type(elvi1))
# Out:
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# 10) Asignar a una variable, la suma de un número entero y otro decimal

# %%
num3 = 5 + 5.5
print(num3)
# Out:
# 10.5

# %% [markdown]
# 11) Realizar una operación de suma de números complejos

# %%
num4 = 3 + 3j
num5 = 6 -2j
print(num4+num5)
# Out:
# (9+1j)

# %% [markdown]
# 12) Realizar una operación de suma de un número real y otro complejo

# %%
print(num1+num5)
# Out:
# (11-2j)

# %% [markdown]
# 13) Realizar una operación de multiplicación

# %%
print(num1*3)
# Out:
# 15

# %% [markdown]
# 14) Mostrar el resultado de elevar 2 a la octava potencia

# %%
print(2**8)
# Out:
# 256

# %% [markdown]
# 15) Obtener el cociente de la división de 27 entre 4 en una variable y luego mostrarla

# %%
num6 = 27
num7 = 4
print(num6/num7)
# Out:
# 6.75

# %% [markdown]
# 16) De la división anterior solamente mostrar la parte entera

# %%
print(27//4)
# Out:
# 6

# %% [markdown]
# 17) De la división de 27 entre 4 mostrar solamente el resto

# %%
print(27%4)
# Out:
# 3

# %% [markdown]
# 18) Utilizando como operandos el número 4 y los resultados obtenidos en los puntos 16 y 17. Obtener 27 como resultado

# %%
print(4*6 +3)
# Out:
# 27

# %% [markdown]
# 19) Utilizar el operador "+" en una operación donde intervengan solo variables alfanuméricas

# %%
lastname = " Reyes"
print(name + lastname)
# Out:
# Rhonald Reyes

# %% [markdown]
# 20) Evaluar si "2" es igual a 2. ¿Por qué ocurre eso?

# %%
print(2 == "2")
#Ocurre porque uno es un sting y el otro un entero.
# Out:
# False

# %% [markdown]
# 21) Utilizar las funciones de cambio de tipo de dato, para que la validación del punto 20 resulte verdadera

# %%
print(2 == int("2"))
# Out:
# True

# %% [markdown]
# 22) ¿Por qué arroja error el siguiente cambio de tipo de datos? a = float('3,8')

# %%
a = float("3,8")
#Ocurre porque al utilizar la coma, en lugar del punto, lo reconoce como una cadena 
# de texto y no puede transformarlo en float. Si se usa el punto, si lo transforma.

# %% [markdown]
# 23) Crear una variable con el valor 3, y utilizar el operador '-=' para modificar su contenido y que de como resultado 2.

# %%
num8 = 3
num8 -= 1
print(num8)
# Out:
# 2

# %% [markdown]
# 24) Realizar la operacion 1 << 2 ¿Por qué da ese resultado? ¿Qué es el sistema de numeración binario?

# %%
1 << 2
#El sistema de numeración binario es un sistema representado solo por 1 y 0. 
#Este resultado se da, porque el viario de 1 es 000000001 (sin imprtar el número de ceros a la izquierda),
#al pedirle que se desplace el 1 dos espacios nos queda 0000100, que es el equivalente a 4
# Out:
# 4

# %% [markdown]
# 25) Realizar la operación 2 + '2' ¿Por qué no está permitido? ¿Si los dos operandos serían del mismo tipo, siempre arrojaría el mismo resultado?

# %%
2 + "2"
#La operación nos arroja error porque uno es una string y el otro un int. No es posible sumarlos ni concatenarlos
#No, no daría lo mismo. Haciendo 2 + 2 realizaría una suma de int arrojando 4 como resultado.
#mientras que hacendo "2" + "2", concatenaría ambas string dando 22 como resultado.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Elvi\Desktop\Python-Prep\M03_variablesydatos\Prep_Course_Homework_03.ipynb Cell 51 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Elvi/Desktop/Python-Prep/M03_variablesydatos/Prep_Course_Homework_03.ipynb#Y101sZmlsZQ%3D%3D?line=0'>1</a> 2 + "2"
#       <a href='vscode-notebook-cell:/c%3A/Users/Elvi/Desktop/Python-Prep/M03_variablesydatos/Prep_Course_Homework_03.ipynb#Y101sZmlsZQ%3D%3D?line=1'>2</a> #La operación nos arroja error porque uno es una string y el otro un int. No es posible sumarlos ni concatenarlos
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# 26) Realizar una operación válida entre valores de tipo entero y string

# %%
a = "Ja"
b = "Si fue gracioso"
print(a*5 + " " + b)
# Out:
# JaJaJaJaJa Si fue gracioso
